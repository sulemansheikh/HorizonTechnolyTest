# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: You are using pip version 21.3.1; however, version 22.2 is available.
# You should consider upgrading via the 'C:\Users\Suleman\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
pip install ipython-sql
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13699 sha256=29d7d95ed3312376ec6f98db2ebcc2c5c3b4527e64bb4ef08accb86041998d89
#   Stored in directory: c:\users\suleman\appdata\local\pip\cache\wheels\48\6d\77\9517cb933af254f51a446f1a5ec9c2be3e45f17384940bce68
# Successfully built prettytable
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# ...

# %%
pip install mysqlclient
# Out:
# ...
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: You are using pip version 21.3.1; however, version 22.2 is available.
# You should consider upgrading via the 'C:\Users\Suleman\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ystan (c:\users\suleman\anaconda3\lib\site-packages)
# WARNING: You are using pip version 21.3.1; however, version 22.2 is available.
# You should consider upgrading via the 'C:\Users\Suleman\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import pymysql

# %%
conn=pymysql.connect(host='localhost',port=int(3306),user='root',passwd='suleman123',db='fertilitypartners')

# %%
df=pd.read_sql_query("SELECT * FROM paitent_Info ",conn)
df
# Out:
#    Patient_ID Patient_Name Patient_Gender  Patient_Phone          Province  \
# 0           1          Ali              M    12507384957           Ontario
# 1           2       Salima              F    12506482904  British Columbia
# 2           3        Ahmed              M    12507483947           Ontario
# 3           4        Sania              F    12502748001           Ontario
# 4           5         Sana              F    12505832224           Ontario
# 5           6        Imran              M    12505099922  British Columbia
# 6           7       Rizwan              M    12505992244          Ontarioo
# 7           8         Sara              F    12505992343           Ontario
# 8           9       Alisha              F    12505998573  British Columbia
# 9          10       Yaseem              F    12505998239  British Columbia
#
#    created_at
# 0  2022-07-04
# 1  2022-07-06
# 2  2022-07-06
# 3  2022-07-07
# 4  2022-07-08
# 5  2022-07-12
# 6  2022-08-12
# 7  2022-08-12
# ...

# %%
df1=pd.read_sql_query("Select * from partner_mapping",conn)

# %%
df1
# Out:
#    Patient_Partner_ID  Patient_ID  Partner_ID
# 0                   1           1           4
# 1                   2           2           3
# 2                   3           3           2
# 3                   4           4           1
# 4                   5           5           6
# 5                   6           6           5
# 6                   7           7           8
# 7                   8           8           7

# %%
# Getting Primary Patient Information 
df1.merge(df, left_on='Patient_ID', right_on='Patient_ID')
# Out:
#    Patient_Partner_ID  Patient_ID  Partner_ID Patient_Name Patient_Gender  \
# 0                   1           1           4          Ali              M
# 1                   2           2           3       Salima              F
# 2                   3           3           2        Ahmed              M
# 3                   4           4           1        Sania              F
# 4                   5           5           6         Sana              F
# 5                   6           6           5        Imran              M
# 6                   7           7           8       Rizwan              M
# 7                   8           8           7         Sara              F
#
#    Patient_Phone          Province  created_at
# 0    12507384957           Ontario  2022-07-04
# 1    12506482904  British Columbia  2022-07-06
# 2    12507483947           Ontario  2022-07-06
# 3    12502748001           Ontario  2022-07-07
# 4    12505832224           Ontario  2022-07-08
# ...

# %%
# Getting patient which have no partners
pd.merge(df1,df, how='right', on='Patient_ID').isna
# Out:
# <bound method DataFrame.isna of    Patient_Partner_ID  Patient_ID  Partner_ID Patient_Name Patient_Gender  \
# 0                 1.0           1         4.0          Ali              M
# 1                 2.0           2         3.0       Salima              F
# 2                 3.0           3         2.0        Ahmed              M
# 3                 4.0           4         1.0        Sania              F
# 4                 5.0           5         6.0         Sana              F
# 5                 6.0           6         5.0        Imran              M
# 6                 7.0           7         8.0       Rizwan              M
# 7                 8.0           8         7.0         Sara              F
# 8                 NaN           9         NaN       Alisha              F
# 9                 NaN          10         NaN       Yaseem              F
#
#    Patient_Phone          Province  created_at
# 0    12507384957           Ontario  2022-07-04
# ...

# %%
# merging both table
df.merge(df1, how='left', on='Patient_ID')
# Out:
#    Patient_ID Patient_Name Patient_Gender  Patient_Phone          Province  \
# 0           1          Ali              M    12507384957           Ontario
# 1           2       Salima              F    12506482904  British Columbia
# 2           3        Ahmed              M    12507483947           Ontario
# 3           4        Sania              F    12502748001           Ontario
# 4           5         Sana              F    12505832224           Ontario
# 5           6        Imran              M    12505099922  British Columbia
# 6           7       Rizwan              M    12505992244          Ontarioo
# 7           8         Sara              F    12505992343           Ontario
# 8           9       Alisha              F    12505998573  British Columbia
# 9          10       Yaseem              F    12505998239  British Columbia
#
#    created_at  Patient_Partner_ID  Partner_ID
# 0  2022-07-04                 1.0         4.0
# 1  2022-07-06                 2.0         3.0
# ...

# %%
# Getting number of patient province-wise
df3=pd.read_sql_query("SELECT Province, COUNT(*) From paitent_Info GROUP BY Province; ",conn)

# %%
df3
# Out:
#            Province  COUNT(*)
# 0           Ontario         5
# 1  British Columbia         4
# 2          Ontarioo         1

# %%
d = {'Referrals': [5,8,6,4,5,6,7,8,5,10,7,13], 'Months': ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']}

# %%
df5 = pd.DataFrame(data=d)

# %%
# Create Table with number of Referrals 

df5
# Out:
#     Referrals Months
# 0           5    Jan
# 1           8    Feb
# 2           6    Mar
# 3           4    Apr
# 4           5    May
# 5           6    Jun
# 6           7    Jul
# 7           8    Aug
# 8           5    Sep
# 9          10    Oct
# 10          7    Nov
# 11         13    Dec
